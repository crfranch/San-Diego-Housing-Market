# %%
import selenium
from selenium import webdriver
import csv
import pandas as pd

# %%
driver = webdriver.Chrome()

# %%
property_shark = 'https://www.propertyshark.com/mason/Street-Index/CA/San-Diego-County/'
# driver.get(property_shark)

# %%
addresses = "resources/addresses.csv"
address_df = pd.read_csv(addresses)

# %%
address_df
# Out:
#       Zip_Code                     Street_Name House_Number  \
# 0        91910                     Castana Plz         1058
# 1        91910                       Bonita Rd           31
# 2        91910              Woodlawn Ave APT D          424
# 3        91910                         Fig Ave          538
# 4        91910                        Calma Dr          922
# 5        91910                    G St SPC 120          677
# 6        91910                   Montebello St           57
# 7        91910                       Minot Ave          216
# 8        91910                            J St           95
# 9        91910                      Hilltop Dr          271
# 10       91910                            H St           69
# 11       91910                       Vista Way          446
# 12       91910                     Palencia Pl          933
# 13       91910                   Terra Nova Dr          707
# 14       91910                       Murray St           66
# 15       91910                          E J St          474
# 16       91910                  Windjammer Cir          323
# 17       91910                     Via Sinuoso          993
# 18       91910                 Buena Vista Way         1056
# 19       91910                            I St          101
# 20       91910                        Doran Ct           37
# 21       91910                          E J St           37
# 22       91910                 Tamayo Dr APT 1          845
# 23       91910                            G St          691
# 24       91910                    E St UNIT 32          569
# 25       91910                Calle De Damasco         1155
# 26       91910       Callejon Palacios UNIT 50         1390
# 27       91910              Center St UNIT 324          376
# 28       91910                  3rd Ave UNIT 2           80
# 29       91910                         1st Ave          114
# ...        ...                             ...          ...
# 8068     92067         Niemann Ranch Rd LOT 79           79
# 8069     92067          Rancho Diegueno LOT 15         5872
# 8070     92067               Connemara Dr # 02            2
# 8071     92067           Niemann Ranch Rd # 79           79
# 8072     92067           Paseo Delicias # 6405         6405
# 8073     92067  1 2 & 6 Camino De Arriba LOT 2         Lots
# 8074     92067             Paseo Valencia # 31         6206
# 8075     92067                 Ambiente LOT 15          Via
# 8076     92067          202 Via Ambiente LOT 2          Lot
# 8077     92067          23 Via Ambiente LOT 23          Lot
# 8078     92067           Niemann Ranch Rd # 43            0
# 8079     92067      Las Palomas LOT 268-290-20            0
# 8080     92067              90 El Brazo LOT 90          Lot
# 8081     92067             Rancho Cielo LOT 21           21
# 8082     92067                     Brazo # 82A           EL
# 8083     92067           Paseo Valencia LOT 31         6206
# 8084     92067         Rancho Diegueno 15 # 15         5872
# 8085     92067                   Brazo LOT 82A           EL
# 8086     92067           87 El Brazo 87 LOT 87          Lot
# 8087     92067         Paseo Delicias LOT 6405         6405
# 8088     92067          Aliso Canyon Rd LOT 00        18531
# 8089     92067         Niemann Ranch Rd LOT 43            0
# 8090     92067         Niemann Ranch Rd LOT 78           78
# 8091     92067              Rancho Cielo LOT 6          Via
# 8092     92067                   Mimulus LOT 0            0
# 8093     92067                 Dalia Dr LOT 80            0
# 8094     92067                       De Arriba       Camino
# 8095     92067                      Andrews Rd        Saint
# 8096     92067                      De Fortuna          Via
# 8097     92067                        Del Alba          Via
#
#                      Street_Name_URL
# 0                        Castana-Plz
# 1                          Bonita-Rd
# 2                 Woodlawn-Ave-APT-D
# 3                            Fig-Ave
# 4                           Calma-Dr
# 5                       G-St-SPC-120
# 6                      Montebello-St
# 7                          Minot-Ave
# 8                               J-St
# 9                         Hilltop-Dr
# 10                              H-St
# 11                         Vista-Way
# 12                       Palencia-Pl
# 13                     Terra-Nova-Dr
# 14                         Murray-St
# 15                            E-J-St
# 16                    Windjammer-Cir
# 17                       Via-Sinuoso
# 18                   Buena-Vista-Way
# 19                              I-St
# 20                          Doran-Ct
# 21                            E-J-St
# 22                   Tamayo-Dr-APT-1
# 23                              G-St
# 24                      E-St-UNIT-32
# 25                  Calle-De-Damasco
# 26         Callejon-Palacios-UNIT-50
# 27                Center-St-UNIT-324
# 28                    3rd-Ave-UNIT-2
# 29                           1st-Ave
# ...                              ...
# 8068         Niemann-Ranch-Rd-LOT-79
# 8069          Rancho-Diegueno-LOT-15
# 8070               Connemara-Dr-#-02
# 8071           Niemann-Ranch-Rd-#-79
# 8072           Paseo-Delicias-#-6405
# 8073  1-2-&-6-Camino-De-Arriba-LOT-2
# 8074             Paseo-Valencia-#-31
# 8075                 Ambiente-LOT-15
# 8076          202-Via-Ambiente-LOT-2
# 8077          23-Via-Ambiente-LOT-23
# 8078           Niemann-Ranch-Rd-#-43
# 8079      Las-Palomas-LOT-268-290-20
# 8080              90-El-Brazo-LOT-90
# 8081             Rancho-Cielo-LOT-21
# 8082                     Brazo-#-82A
# 8083           Paseo-Valencia-LOT-31
# 8084         Rancho-Diegueno-15-#-15
# 8085                   Brazo-LOT-82A
# 8086           87-El-Brazo-87-LOT-87
# 8087         Paseo-Delicias-LOT-6405
# 8088          Aliso-Canyon-Rd-LOT-00
# 8089         Niemann-Ranch-Rd-LOT-43
# 8090         Niemann-Ranch-Rd-LOT-78
# 8091              Rancho-Cielo-LOT-6
# 8092                   Mimulus-LOT-0
# 8093                 Dalia-Dr-LOT-80
# 8094                       De-Arriba
# 8095                      Andrews-Rd
# 8096                      De-Fortuna
# 8097                        Del-Alba
#
# [8098 rows x 4 columns]

# %%
# for loop on zip code 
    # create databases that filters by each zipcode
    # make that database equal a variable 
    # store that variable in a list

# %%
zip_list = []
street_list = []
number_list = []
for i, row in address_df.iterrows():
    i = row["Zip_Code"]
    zip_list.append(i)
    i = row["Street_Name"]
    street_list.append(i)
    i = row["House_Number"]
    number_list.append(i)
    #df_filtered = address_df.query(f'Zip_Code=={i}')
    #Street_Name = row['Street Name']
    #House_Number = row['House Number']
    #driver.get(property_shark+str(zip_code))
# street_list

# %%
# zip_list = list(dict.fromkeys(zip_list))
# street_list = list(dict.fromkeys(street_list))
# number_list = list(dict.fromkeys(number_list))

# %%
# zip_list

# %%
# street_list

# %%
# number_list

# %%
addresses = []
neighborhood_list = []
Achorage_list = []
square_footage_list = []
year_built_list = []
Parcel_ID_list = []
Property_class_list = []
Legal_description_list = []
units_list = []
bath_list = []
bed_list = []

# for zipcode in zip_list:
#     zipcode = str(zipcode)
#     zip_shark = property_shark + zipcode
#     driver.get(zip_shark)
#     for street in street_list:
#         try: 
#             street = str(street)
#             street_code = driver.find_element_by_partial_link_text(street)
#             street_code.click()
#             for address in number_list:
for i, row in address_df.iterrows():
    zip_code = str(row["Zip_Code"])
    street_name = str(row["Street_Name"])
    address = str(row["House_Number"])
    street_URL = str(row["Street_Name_URL"])
    zip_shark = property_shark + zip_code +'/' + street_URL
    driver.get(zip_shark)
    try: 
        address_link = str(f"{address} {street_name}")
        address_code = driver.find_element_by_link_text(address_link)
        address_code.click()
        try:
            street_number = driver.find_element_by_xpath('//*[@id="nationwide/property_details_content"]/div/div[1]/table/tbody/tr[1]/td/table/tbody/tr/td').text
            addresses.append(street_number)
        except:
            addresses.append("NA")
        try:
            square_footage = driver.find_element_by_xpath('//*[@id="nationwide/property_details_content"]/div/div[2]/table/tbody/tr[3]/td/table/tbody/tr/td').text
            square_footage_list.append(square_footage)
        except:
            square_footage_list.append("NA")
        try:
            year_built = driver.find_element_by_xpath('//*[@id="nationwide/property_details_content"]/div/div[2]/table/tbody/tr[4]/td/table/tbody/tr/td').text
            year_built_list.append(year_built)
        except:
            year_built_list.append("NA")
        try:
            Parcel_ID = driver.find_element_by_xpath('//*[@id="nationwide/property_details_content"]/div/div[1]/table/tbody/tr[3]/td/table/tbody/tr/td').text
            Parcel_ID_list.append(Parcel_ID)
        except:
            Parcel_ID_list.append("NA")
        try: 
            Property_class = driver.find_element_by_xpath('//*[@id="nationwide/property_details_content"]/div/div[2]/table/tbody/tr[1]/td/table/tbody/tr/td').text
            Property_class_list.append(Property_class)
        except:
            Property_class_list.append("NA")
        try:
            Legal_description = driver.find_element_by_xpath('//*[@id="nationwide/property_details_content"]/div/div[1]/table/tbody/tr[4]/td/table/tbody/tr/td').text
            Legal_description_list.append(Legal_description)
        except:
            Legal_description_list.append("NA")
        try: 
            units = driver.find_element_by_xpath('//*[@id="nationwide/property_details_content"]/div/div[2]/table/tbody/tr[5]/td/table/tbody/tr/td').text
            units_list.append(units)
        except:
            units_list.append("NA")
        try:
            bath = driver.find_element_by_xpath('//*[@id="nationwide/property_details_content"]/div/div[2]/table/tbody/tr[7]/td/table/tbody/tr/td').text
            bath_list.append(bath)
        except:
            bath_list.append("NA")
        try:
            bed = driver.find_element_by_xpath('//*[@id="nationwide/property_details_content"]/div/div[2]/table/tbody/tr[6]/td/table/tbody/tr/td').text
            bed_list.append(bed)
        except:
            bed_list.append("NA")
        try:
            Neighborhood = driver.find_element_by_xpath('//*[@id="nationwide/property_details_content"]/div/div[1]/table/tbody/tr[5]/td/table/tbody/tr/td').text
            neighborhood_list.append(Neighborhood)
        except:
            neighborhood_list.append("NA")
        try:
            Achorage = driver.find_element_by_xpath('//*[@id="nationwide/property_details_content"]/div/div[1]/table/tbody/tr[5]/td/table/tbody/tr/td').text
            Achorage_list.append(Achorage)
        except:
            Achorage_list.append("NA")
        print("Successs")
    except:
        print(f"{address} {street_name} is Not applicable")
# Out:
# 1058 Castana Plz is Not applicable
# Successs
# 424 Woodlawn Ave APT D is Not applicable
# Successs
# Successs
# 677 G St SPC 120 is Not applicable
# Successs
# Successs
# 95 J St is Not applicable
# Successs
# Successs
# Successs
# 933 Palencia Pl is Not applicable
# Successs
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
#
# KeyboardInterrupt

# %%
# neighborhood_list

# %%
Property_shark_df = pd.DataFrame({'address': addresses, 'neighborhood': neighborhood_list, 'Acorage': Achorage_list, 'SQFT': square_footage_list, 'year built': year_built_list, 'Parcel ID': Parcel_ID_list, 'Property Class': Property_class_list, 'Legal Description': Legal_description_list, 'units': units_list, 'bath': bath_list, 'bed':bed_list})
Property_shark_df

# %%
Property_shark_df.to_csv(r'C:\Users\Jeffh\Documents\Bootcamp\ETL_Project\San-Diego-Housing-Market\zillow.csv')
