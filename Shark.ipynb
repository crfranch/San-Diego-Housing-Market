# %%
import selenium
from selenium import webdriver
import csv
import pandas as pd

# %%
driver = webdriver.Chrome()

# %%
property_shark = 'https://www.propertyshark.com/mason/Street-Index/CA/San-Diego-County/'
# driver.get(property_shark)

# %%
addresses = "property_shark_excel_clean.csv"
address_df = pd.read_csv(addresses)

# %%
address_df
# Out:
#                                                 address         neighborhood  \
# 0                  922 Calma Dr,\nChula Vista, CA 91910       Rancho Del Rey
# 1             933 Palencia Pl,\r\nChula Vista, CA 91910       Rancho Del Rey
# 2           707 Terra Nova Dr,\r\nChula Vista, CA 91910       Rancho Del Rey
# 3             993 Via Sinuoso,\r\nChula Vista, CA 91910       Rancho Del Rey
# 4               522 Beacon Pl,\r\nChula Vista, CA 91910           Terra Nova
# 5        1052 Camino Espuelas,\r\nChula Vista, CA 91910       Rancho Del Rey
# 6                42 Vista Way,\r\nChula Vista, CA 91910           Eucalyptus
# 7           508 Plaza Del Cid,\r\nChula Vista, CA 91910       Rancho Del Rey
# 8                737 Duoro Dr,\r\nChula Vista, CA 91910       Rancho Del Rey
# 9             720 Cardona Ave,\r\nChula Vista, CA 91910       Rancho Del Rey
# 10           28 Las Flores Dr,\r\nChula Vista, CA 91910           Eucalyptus
# 11          412 Milagrosa Cir,\r\nChula Vista, CA 91910       Rancho Del Rey
# 12             613 Claire Ave,\r\nChula Vista, CA 91910              Hilltop
# 13           147 Woodlawn Ave,\r\nChula Vista, CA 91910    North Chula Vista
# 14             459 Manzano Pl,\r\nChula Vista, CA 91910       Rancho Del Rey
# 15         136 Brightwood Ave,\r\nChula Vista, CA 91910    North Chula Vista
# 16            495 Davidson St,\r\nChula Vista, CA 91910  Central Chula Vista
# 17               390 Vance St,\r\nChula Vista, CA 91910  Central Chula Vista
# 18          8033 Los Sabalos St,\r\nSan Diego, CA 92126            Mira Mesa
# 19               7735 Caffey Ln,\r\nSan Diego, CA 92126            Mira Mesa
# 20        6720 Lopez Canyon Way,\r\nSan Diego, CA 92126      Sorrento Valley
# 21           11864 River Rim Rd,\r\nSan Diego, CA 92126            Mira Mesa
# 22             7926 Flanders Dr,\r\nSan Diego, CA 92126            Mira Mesa
# 23               1428 Owen Dr,\r\nChula Vista, CA 91911               Sunbow
# 24             474 Nickman St,\r\nChula Vista, CA 91911           Harborside
# 25           954 Kittiwake Ln,\r\nChula Vista, CA 91911           Harborside
# 26             240 Tremont St,\r\nChula Vista, CA 91911            Otay Town
# 27             519 Arizona St,\r\nChula Vista, CA 91911           Harborside
# 28            2 Tamarindo Way,\r\nChula Vista, CA 91911            Otay Town
# 29             1692 Derek Way,\r\nChula Vista, CA 91911          Castle Park
# ...                                                 ...                  ...
# 1456      1314 Camino Carmelo,\r\nChula Vista, CA 91913           Otay Ranch
# 1457      1310 Camino Carmelo,\r\nChula Vista, CA 91913           Otay Ranch
# 1458        1154 Camino Prado,\r\nChula Vista, CA 91913           Otay Ranch
# 1459       969 Camino Cantera,\r\nChula Vista, CA 91913           Otay Ranch
# 16    Central Chula Vista  1,673      1955.0  568-011-15-00
# 17    Central Chula Vista    892      1950.0  568-411-18-00
# 18              Mira Mesa  2,017      1990.0  309-530-61-00
# 19              Mira Mesa  1,266      1985.0  341-295-10-00
# 20        Sorrento Valley  2,508      2013.0  311-650-59-00
# 21              Mira Mesa  2,102      1988.0  309-501-67-00
# 22              Mira Mesa  1,008      1979.0  311-335-22-00
# 23                 Sunbow  2,373      2000.0  641-121-25-00
# 24             Harborside  1,602      1954.0  618-181-04-00
# 25             Harborside  2,178      1966.0  618-400-03-00
# 26              Otay Town    917      1930.0  623-151-19-00
# 27             Harborside  1,440      1965.0  618-390-15-00
# 28              Otay Town  1,870      2014.0  623-343-16-00
# 29            Castle Park  1,469      1989.0  624-450-12-00
# ...                   ...    ...         ...            ...
# 1456           Otay Ranch    NaN         NaN  644-387-64-00
# 1457           Otay Ranch    NaN         NaN  644-387-65-00
# 1458           Otay Ranch    NaN         NaN  644-388-09-00
# 1459           Otay Ranch    NaN         NaN  644-381-29-00
# 1460           Otay Ranch    NaN         NaN  644-381-22-00
# 1461           Otay Ranch    NaN         NaN  644-381-35-00
# 1462           Otay Ranch    NaN         NaN  644-381-21-00
# 1463           Otay Ranch    NaN         NaN  644-381-23-00
# 1464           Otay Ranch    NaN         NaN  644-387-70-00
# 1465           Otay Ranch    NaN         NaN  644-387-72-00
# 1466           Otay Ranch    NaN         NaN  644-381-07-00
# 1467           Otay Ranch    NaN         NaN  644-381-20-00
# 1468           Otay Ranch    NaN         NaN  644-381-16-00
# 1469           Otay Ranch    NaN         NaN  644-387-69-00
# 1470                  NaN    NaN         NaN  228-120-09-00
# 1471                  NaN    NaN         NaN  536-132-03-00
# 1472             La Playa    NaN         NaN  760-003-01-00
# 1473                  NaN    NaN         NaN  235-581-06-00
# 1474                  NaN    NaN         NaN  235-610-27-00
# 1475                  NaN    NaN         NaN  235-610-43-00
# 1476                  NaN    NaN         NaN  235-610-19-00
# 1477                  NaN    NaN         NaN  235-610-42-00
# 1478                  NaN    NaN         NaN  235-610-23-00
# 1479                  NaN    NaN         NaN  228-381-67-00
# 1480                  NaN    NaN         NaN  300-060-21-00
# 1481                  NaN    NaN         NaN  260-363-31-00
# 1482                  NaN    NaN         NaN  260-182-17-00
# 1483                  NaN    NaN         NaN  260-182-17-00
# 1484  Rolling Hills Ranch    NaN         NaN  595-848-08-00
# 1485  Rolling Hills Ranch    NaN         NaN  585-222-20-00
#
#                     Property Class                        Legal Description  \
# 0     Single Family Residence (11)                                   LOT 19
# 1     Single Family Residence (11)                                   LOT 73
# 2     Single Family Residence (11)                                    LOT 2
# 3     Single Family Residence (11)                                    LOT 7
# 4     Single Family Residence (11)                                  LOT 300
# 5     Single Family Residence (11)                                   LOT 50
# 6     Single Family Residence (11)                                    LOT 9
# 7     Single Family Residence (11)                                   LOT 62
# 8     Single Family Residence (11)                                   LOT 41
# 9     Single Family Residence (11)                                   LOT 62
# 10    Single Family Residence (11)                                    LOT 5
# 12      2.0   2.5  5.0  91910
# 13      1.0   1.0  2.0  91910
# 14      1.0   5.5  6.0  91910
# 15      1.0   1.0  3.0  91910
# 16      2.0   2.0  4.0  91910
# 17      1.0   1.0  2.0  91910
# 18      1.0   3.0  4.0  92126
# 19      1.0   2.0  3.0  92126
# 20      1.0   3.0  4.0  92126
# 21      1.0   2.5  4.0  92126
# 22      1.0   2.0  2.0  92126
# 23      1.0   3.0  5.0  91911
# 24      1.0   1.5  4.0  91911
# 25      1.0   2.0  5.0  91911
# 26      1.0   2.0  3.0  91911
# 27      1.0   2.0  4.0  91911
# 28      1.0   3.0  4.0  91911
# 29      1.0   2.5  3.0  91911
# ...     ...   ...  ...    ...
# 1456    NaN   NaN  NaN  91913
# 1457    NaN   NaN  NaN  91913
# 1458    NaN   NaN  NaN  91913
# 1459    NaN   NaN  NaN  91913
# 1460    NaN   NaN  NaN  91913
# 1461    NaN   NaN  NaN  91913
# 1462    NaN   NaN  NaN  91913
# 1463    NaN   NaN  NaN  91913
# 1464    NaN   NaN  NaN  91913
# 1465    NaN   NaN  NaN  91913
# 1466    NaN   NaN  NaN  91913
# 1467    NaN   NaN  NaN  91913
# 1468    NaN   NaN  NaN  91913
# 1469    NaN   NaN  NaN  91913
# 1470    NaN   NaN  NaN  92069
# 1471    NaN   NaN  NaN  92118
# 1472    NaN   NaN  NaN  92106
# 1473    NaN   NaN  NaN  92029
# 1474    NaN   NaN  NaN  92029
# 1475    NaN   NaN  NaN  92029
# 1476    NaN   NaN  NaN  92029
# 1477    NaN   NaN  NaN  92029
# 1478    NaN   NaN  NaN  92029
# 1479    NaN   NaN  NaN  92029
# 1480    NaN   NaN  NaN  92014
# 1481    NaN   NaN  NaN  92007
# 1482    NaN   NaN  NaN  92007
# 1483    NaN   NaN  NaN  92007
# 1484    NaN   NaN  NaN  91914
# 1485    NaN   NaN  NaN  91914
#
# [1486 rows x 12 columns]

# %%
# for loop on zip code 
    # create databases that filters by each zipcode
    # make that database equal a variable 
    # store that variable in a list

# %%
zip_list = []
street_list = []
number_list = []
for i, row in address_df.iterrows():
    i = row["Zip_Code"]
    zip_list.append(i)
    i = row["Street_Name"]
    street_list.append(i)
    i = row["House_Number"]
    number_list.append(i)
    #df_filtered = address_df.query(f'Zip_Code=={i}')
    #Street_Name = row['Street Name']
    #House_Number = row['House Number']
    #driver.get(property_shark+str(zip_code))
# street_list

# %%
# zip_list = list(dict.fromkeys(zip_list))
# street_list = list(dict.fromkeys(street_list))
# number_list = list(dict.fromkeys(number_list))

# %%
# zip_list

# %%
# street_list

# %%
# number_list

# %%
addresses = []
neighborhood_list = []
Achorage_list = []
square_footage_list = []
year_built_list = []
Parcel_ID_list = []
Property_class_list = []
Legal_description_list = []
units_list = []
bath_list = []
bed_list = []

# for zipcode in zip_list:
#     zipcode = str(zipcode)
#     zip_shark = property_shark + zipcode
#     driver.get(zip_shark)
#     for street in street_list:
#         try: 
#             street = str(street)
#             street_code = driver.find_element_by_partial_link_text(street)
#             street_code.click()
#             for address in number_list:
for i, row in address_df.iterrows():
    zip_code = str(row["Zip_Code"])
    street_name = str(row["Street_Name"])
    address = str(row["House_Number"])
    street_URL = str(row["Street_Name_URL"])
    zip_shark = property_shark + zip_code +'/' + street_URL
    driver.get(zip_shark)
    try: 
        address_link = str(f"{address} {street_name}")
        address_code = driver.find_element_by_link_text(address_link)
        address_code.click()
        try:
            street_number = driver.find_element_by_xpath('//*[@id="nationwide/property_details_content"]/div/div[1]/table/tbody/tr[1]/td/table/tbody/tr/td').text
            addresses.append(street_number)
        except:
            addresses.append("NA")
        try:
            square_footage = driver.find_element_by_xpath('//*[@id="nationwide/property_details_content"]/div/div[2]/table/tbody/tr[3]/td/table/tbody/tr/td').text
            square_footage_list.append(square_footage)
        except:
            square_footage_list.append("NA")
        try:
            year_built = driver.find_element_by_xpath('//*[@id="nationwide/property_details_content"]/div/div[2]/table/tbody/tr[4]/td/table/tbody/tr/td').text
            year_built_list.append(year_built)
        except:
            year_built_list.append("NA")
        try:
            Parcel_ID = driver.find_element_by_xpath('//*[@id="nationwide/property_details_content"]/div/div[1]/table/tbody/tr[3]/td/table/tbody/tr/td').text
            Parcel_ID_list.append(Parcel_ID)
        except:
            Parcel_ID_list.append("NA")
        try: 
            Property_class = driver.find_element_by_xpath('//*[@id="nationwide/property_details_content"]/div/div[2]/table/tbody/tr[1]/td/table/tbody/tr/td').text
            Property_class_list.append(Property_class)
        except:
            Property_class_list.append("NA")
        try:
            Legal_description = driver.find_element_by_xpath('//*[@id="nationwide/property_details_content"]/div/div[1]/table/tbody/tr[4]/td/table/tbody/tr/td').text
            Legal_description_list.append(Legal_description)
        except:
            Legal_description_list.append("NA")
        try: 
            units = driver.find_element_by_xpath('//*[@id="nationwide/property_details_content"]/div/div[2]/table/tbody/tr[5]/td/table/tbody/tr/td').text
            units_list.append(units)
        except:
            units_list.append("NA")
        try:
            bath = driver.find_element_by_xpath('//*[@id="nationwide/property_details_content"]/div/div[2]/table/tbody/tr[7]/td/table/tbody/tr/td').text
            bath_list.append(bath)
        except:
            bath_list.append("NA")
        try:
            bed = driver.find_element_by_xpath('//*[@id="nationwide/property_details_content"]/div/div[2]/table/tbody/tr[6]/td/table/tbody/tr/td').text
            bed_list.append(bed)
        except:
            bed_list.append("NA")
        try:
            Neighborhood = driver.find_element_by_xpath('//*[@id="nationwide/property_details_content"]/div/div[1]/table/tbody/tr[5]/td/table/tbody/tr/td').text
            neighborhood_list.append(Neighborhood)
        except:
            neighborhood_list.append("NA")
        try:
            Achorage = driver.find_element_by_xpath('//*[@id="nationwide/property_details_content"]/div/div[1]/table/tbody/tr[5]/td/table/tbody/tr/td').text
            Achorage_list.append(Achorage)
        except:
            Achorage_list.append("NA")
        print("Successs")
    except:
        print(f"{address} {street_name} is Not applicable")
# Out:
# 1058 Castana Plz is Not applicable
# Successs
# 424 Woodlawn Ave APT D is Not applicable
# Successs
# Successs
# 677 G St SPC 120 is Not applicable
# Successs
# Successs
# 95 J St is Not applicable
# Successs
# Successs
# Successs
# 933 Palencia Pl is Not applicable
# Successs
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
#
# KeyboardInterrupt

# %%
# neighborhood_list

# %%
Property_shark_df = pd.DataFrame({'address': addresses, 'neighborhood': neighborhood_list, 'Acorage': Achorage_list, 'SQFT': square_footage_list, 'year built': year_built_list, 'Parcel ID': Parcel_ID_list, 'Property Class': Property_class_list, 'Legal Description': Legal_description_list, 'units': units_list, 'bath': bath_list, 'bed':bed_list})
Property_shark_df

# %%
Property_shark_df.to_csv(r'C:\Users\Jeffh\Documents\Bootcamp\ETL_Project\San-Diego-Housing-Market\zillow.csv')
